# %%
import cv2
import numpy as np
from ultralytics import YOLO

# تحميل النموذج المدرب
model = YOLO("yolov8n.pt")  # ضع هنا مسار النموذج المدرب على كرة القدم

# تحميل الصورة
image = cv2.imread("frame.jpg")

# تشغيل الكشف
results = model(image)[0]

# استخراج الكائنات
players = []
ball = None

for result in results.boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    cls = int(cls)
    
    # نفترض أن الكلاس 0 هو لاعب، والكلاس 1 هو كرة (حسب التدريب الخاص بك)
    if cls == 0:  # لاعب
        center_x = int((x1 + x2) / 2)
        center_y = int((y1 + y2) / 2)
        players.append({'bbox': (int(x1), int(y1), int(x2), int(y2)), 'center': (center_x, center_y)})
    elif cls == 1:  # كرة
        ball = {'bbox': (int(x1), int(y1), int(x2), int(y2))}

# نفرض أن الفريق المهاجم على اليمين، والتسلل يتم بناءً على موضع الـ x
attacking_team = []
defending_team = []

# تصنيف الفرق بناءً على الموقع الأفقي (يمكن تحسينه لاحقاً بالألوان أو المعرفات)
median_x = np.median([p['center'][0] for p in players])
for p in players:
    if p['center'][0] > median_x:
        attacking_team.append(p)
    else:
        defending_team.append(p)

# تحديد آخر مدافع (أقصى قيمة x في الفريق المدافع)
last_defender_x = max([p['center'][0] for p in defending_team])

# تحديد اللاعبين المتسللين
offside_players = []
for p in attacking_team:
    if p['center'][0] > last_defender_x:
        offside_players.append(p)

# رسم النتائج
for p in players:
    x1, y1, x2, y2 = p['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)

for p in offside_players:
    x1, y1, x2, y2 = p['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
    cv2.putText(image, "OFFSIDE", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# رسم خط التسلل
cv2.line(image, (last_defender_x, 0), (last_defender_x, image.shape[0]), (0, 255, 255), 2)

# حفظ الصورة الناتجة
cv2.imwrite("result.jpg", image)
# Out:
# 0: 384x640 6 persons, 263.7ms
# Speed: 7.1ms preprocess, 263.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# True

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# تحميل النموذج المدرب
model = YOLO("yolov8n.pt")  # غيّر المسار إلى النموذج المدرب على كرة القدم

# تحميل الصورة
image = cv2.imread("frame.jpg")

# تشغيل النموذج على الصورة
results = model(image)[0]

# استخراج الكائنات: لاعبين والكرة
players = []
ball = None

for result in results.boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    cls = int(cls)

    if cls == 0:  # لاعب
        center_x = int((x1 + x2) / 2)
        center_y = int((y1 + y2) / 2)
        players.append({'bbox': (int(x1), int(y1), int(x2), int(y2)), 'center': (center_x, center_y)})
    elif cls == 1:  # كرة
        ball = {'bbox': (int(x1), int(y1), int(x2), int(y2))}

# تقسيم الفريقين بشكل تقريبي حسب المواقع (يمين ويسار)
attacking_team = []
defending_team = []

if len(players) >= 4:
    median_x = np.median([p['center'][0] for p in players])
    for p in players:
        if p['center'][0] > median_x:
            attacking_team.append(p)
        else:
            defending_team.append(p)
else:
    print("عدد اللاعبين قليل جداً لتحديد الفريقين.")
    attacking_team = players  # مؤقتاً نضع الكل كمهاجمين

# حساب موقع آخر مدافع
if defending_team:
    last_defender_x = max([p['center'][0] for p in defending_team])
else:
    last_defender_x = image.shape[1] // 2  # وسط الصورة كبديل

# تحديد أقرب لاعب مهاجم للكرة (يُفترض أنه المستقبل)
potential_offside_player = None
if ball and attacking_team:
    ball_center_x = (ball['bbox'][0] + ball['bbox'][2]) // 2
    ball_center_y = (ball['bbox'][1] + ball['bbox'][3]) // 2

    min_dist = float('inf')
    for p in attacking_team:
        px, py = p['center']
        dist = np.sqrt((px - ball_center_x)**2 + (py - ball_center_y)**2)
        if dist < min_dist:
            min_dist = dist
            potential_offside_player = p

# التحقق إذا كان هذا اللاعب متسلل
if potential_offside_player and potential_offside_player['center'][0] > last_defender_x:
    x1, y1, x2, y2 = potential_offside_player['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
    cv2.putText(image, "OFFSIDE", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# رسم جميع اللاعبين (للتوضيح فقط)
#for p in players:
   # x1, y1, x2, y2 = p['bbox']
   # cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)

# رسم خط التسلل
cv2.line(image, (last_defender_x, 0), (last_defender_x, image.shape[0]), (0, 255, 255), 2)

# حفظ الصورة الناتجة
cv2.imwrite("result1.jpg", image)
print("تم حفظ الصورة باسم result1.jpg")
# Out:
# 0: 384x640 6 persons, 492.7ms
# Speed: 35.0ms preprocess, 492.7ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
# تم حفظ الصورة باسم result1.jpg

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# تحميل النموذج المدرب
model = YOLO("yolov8n.pt")  # استبدل هذا بمسار النموذج المدرب على كرة القدم

# تحميل الصورة
image = cv2.imread("frame.jpg")

# تشغيل النموذج على الصورة
results = model(image)[0]

# استخراج الكائنات: لاعبين والكرة
players = []
ball = None

for result in results.boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    cls = int(cls)

    if cls == 0:  # لاعب
        center_x = int((x1 + x2) / 2)
        center_y = int((y1 + y2) / 2)
        players.append({'bbox': (int(x1), int(y1), int(x2), int(y2)), 'center': (center_x, center_y)})
    elif cls == 1:  # كرة
        ball = {'bbox': (int(x1), int(y1), int(x2), int(y2))}

# تقدير الفريقين
attacking_team = []
defending_team = []

if len(players) >= 4:
    median_x = np.median([p['center'][0] for p in players])
    for p in players:
        if p['center'][0] > median_x:
            attacking_team.append(p)
        else:
            defending_team.append(p)
else:
    attacking_team = players  # مؤقتاً نعتبر الكل مهاجمين

# تحديد آخر مدافع
if defending_team:
    last_defender_x = max([p['center'][0] for p in defending_team])
else:
    last_defender_x = image.shape[1] // 2

# تحديد اللاعب المتسلل بناءً على التمرير
potential_offside_player = None
if ball and attacking_team:
    ball_center_x = (ball['bbox'][0] + ball['bbox'][2]) // 2
    ball_center_y = (ball['bbox'][1] + ball['bbox'][3]) // 2

    min_dist = float('inf')
    for p in attacking_team:
        px, py = p['center']
        dist = np.sqrt((px - ball_center_x)**2 + (py - ball_center_y)**2)
        if dist < min_dist:
            min_dist = dist
            potential_offside_player = p

# التحقق من التسلل
if potential_offside_player and potential_offside_player['center'][0] > last_defender_x:
    x1, y1, x2, y2 = potential_offside_player['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
    cv2.putText(image, "OFFSIDE", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# رسم خط التسلل فقط
cv2.line(image, (last_defender_x, 0), (last_defender_x, image.shape[0]), (0, 255, 255), 2)

# حفظ الصورة
cv2.imwrite("result2.jpg", image)
print("تم حفظ الصورة باسم result2.jpg")
# Out:
# 0: 384x640 6 persons, 277.0ms
# Speed: 15.7ms preprocess, 277.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# تم حفظ الصورة باسم result2.jpg

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# تحميل النموذج المدرب
model = YOLO("yolov8n.pt")  # غيّر هذا لموقع النموذج المدرب الخاص بك

# تحميل الصورة
image = cv2.imread("frame.jpg")

# تشغيل النموذج على الصورة
results = model(image)[0]

# استخراج الكائنات: لاعبين والكرة
players = []
ball = None

for result in results.boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    cls = int(cls)

    if cls == 0:  # لاعب
        center_x = int((x1 + x2) / 2)
        center_y = int((y1 + y2) / 2)
        players.append({'bbox': (int(x1), int(y1), int(x2), int(y2)), 'center': (center_x, center_y)})
    elif cls == 1:  # كرة
        ball = {'bbox': (int(x1), int(y1), int(x2), int(y2))}

# تقدير الفريقين بناءً على الموقع الأفقي للاعبين
attacking_team = []
defending_team = []

if len(players) >= 4:
    median_x = np.median([p['center'][0] for p in players])
    for p in players:
        if p['center'][0] > median_x:
            attacking_team.append(p)
        else:
            defending_team.append(p)
else:
    attacking_team = players  # إذا كان عدد اللاعبين قليل، نعتبر الكل مهاجمين

# تحديد آخر مدافع
if defending_team:
    last_defender_x = max([p['center'][0] for p in defending_team])
else:
    last_defender_x = image.shape[1] // 2  # تحديد خط المنتصف كبديل إذا لم يوجد مدافعين

# تحديد اللاعب المتسلل بناءً على أقرب مسافة للكرة
potential_offside_player = None
if ball and attacking_team:
    ball_center_x = (ball['bbox'][0] + ball['bbox'][2]) // 2
    ball_center_y = (ball['bbox'][1] + ball['bbox'][3]) // 2

    min_dist = float('inf')
    for p in attacking_team:
        px, py = p['center']
        dist = np.sqrt((px - ball_center_x)**2 + (py - ball_center_y)**2)
        if dist < min_dist:
            min_dist = dist
            potential_offside_player = p

# التحقق من التسلل
if potential_offside_player and potential_offside_player['center'][0] > last_defender_x:
    x1, y1, x2, y2 = potential_offside_player['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
    cv2.putText(image, "OFFSIDE", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# رسم خط التسلل
cv2.line(image, (last_defender_x, 0), (last_defender_x, image.shape[0]), (0, 255, 255), 2)

# حفظ الصورة
cv2.imwrite("result3.jpg", image)
print("تم حفظ الصورة باسم result3.jpg")
# Out:
# 0: 384x640 6 persons, 445.0ms
# Speed: 54.5ms preprocess, 445.0ms inference, 39.4ms postprocess per image at shape (1, 3, 384, 640)
# تم حفظ الصورة باسم result3.jpg

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# تحميل النموذج المدرب
model = YOLO("yolov8n.pt")  # غيّر هذا لموقع النموذج المدرب الخاص بك

# تحميل الصورة
image = cv2.imread("frame.jpg")

# تشغيل النموذج على الصورة
results = model(image)[0]

# استخراج الكائنات: لاعبين والكرة
players = []
ball = None

for result in results.boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    cls = int(cls)

    if cls == 0:  # لاعب
        center_x = int((x1 + x2) / 2)
        center_y = int((y1 + y2) / 2)
        players.append({'bbox': (int(x1), int(y1), int(x2), int(y2)), 'center': (center_x, center_y)})
    elif cls == 1:  # كرة
        ball = {'bbox': (int(x1), int(y1), int(x2), int(y2))}

# تقدير الفريقين بناءً على الموقع الأفقي للاعبين
attacking_team = []
defending_team = []

if len(players) >= 4:
    median_x = np.median([p['center'][0] for p in players])
    for p in players:
        if p['center'][0] > median_x:
            attacking_team.append(p)
        else:
            defending_team.append(p)
else:
    attacking_team = players  # إذا كان عدد اللاعبين قليل، نعتبر الكل مهاجمين

# تحديد آخر مدافع
if defending_team:
    last_defender_x = max([p['center'][0] for p in defending_team])
else:
    last_defender_x = image.shape[1] // 2  # تحديد خط المنتصف كبديل إذا لم يوجد مدافعين

# تحديد اللاعب المتسلل بناءً على أقرب مسافة للكرة
potential_offside_player = None
if ball and attacking_team:
    ball_center_x = (ball['bbox'][0] + ball['bbox'][2]) // 2
    ball_center_y = (ball['bbox'][1] + ball['bbox'][3]) // 2

    min_dist = float('inf')
    for p in attacking_team:
        px, py = p['center']
        dist = np.sqrt((px - ball_center_x)**2 + (py - ball_center_y)**2)
        if dist < min_dist:
            min_dist = dist
            potential_offside_player = p

# التحقق من التسلل
if potential_offside_player and potential_offside_player['center'][0] > last_defender_x:
    x1, y1, x2, y2 = potential_offside_player['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
    cv2.putText(image, "OFFSIDE", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# رسم خط التسلل
cv2.line(image, (last_defender_x, 0), (last_defender_x, image.shape[0]), (0, 255, 255), 2)

# حفظ الصورة
cv2.imwrite("result4.jpg", image)
print("تم حفظ الصورة باسم result4.jpg")
# Out:
# 0: 384x640 6 persons, 228.1ms
# Speed: 9.1ms preprocess, 228.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# تم حفظ الصورة باسم result4.jpg

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# تحميل النموذج المدرب
model = YOLO("yolov8n.pt")  # غيّر هذا لموقع النموذج المدرب الخاص بك

# تحميل الصورة
image = cv2.imread("frame1.jpg")

# تشغيل النموذج على الصورة
results = model(image)[0]

# استخراج الكائنات: لاعبين والكرة
players = []
ball = None

for result in results.boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    cls = int(cls)

    if cls == 0:  # لاعب
        center_x = int((x1 + x2) / 2)
        center_y = int((y1 + y2) / 2)
        players.append({'bbox': (int(x1), int(y1), int(x2), int(y2)), 'center': (center_x, center_y)})
    elif cls == 1:  # كرة
        ball = {'bbox': (int(x1), int(y1), int(x2), int(y2))}

# تقدير الفريقين بناءً على الموقع الأفقي للاعبين
attacking_team = []
defending_team = []

if len(players) >= 4:
    median_x = np.median([p['center'][0] for p in players])
    for p in players:
        if p['center'][0] > median_x:
            attacking_team.append(p)
        else:
            defending_team.append(p)
else:
    attacking_team = players  # إذا كان عدد اللاعبين قليل، نعتبر الكل مهاجمين

# تحديد آخر مدافع
if defending_team:
    last_defender_x = max([p['center'][0] for p in defending_team])
else:
    last_defender_x = image.shape[1] // 2  # تحديد خط المنتصف كبديل إذا لم يوجد مدافعين

# تحديد اللاعب المتسلل بناءً على أقرب مسافة للكرة
potential_offside_player = None
if ball and attacking_team:
    ball_center_x = (ball['bbox'][0] + ball['bbox'][2]) // 2
    ball_center_y = (ball['bbox'][1] + ball['bbox'][3]) // 2

    min_dist = float('inf')
    for p in attacking_team:
        px, py = p['center']
        dist = np.sqrt((px - ball_center_x)**2 + (py - ball_center_y)**2)
        if dist < min_dist:
            min_dist = dist
            potential_offside_player = p

# التحقق من التسلل
if potential_offside_player and potential_offside_player['center'][0] > last_defender_x:
    x1, y1, x2, y2 = potential_offside_player['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
    cv2.putText(image, "OFFSIDE", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# رسم خط التسلل
cv2.line(image, (last_defender_x, 0), (last_defender_x, image.shape[0]), (0, 255, 255), 2)

# حفظ الصورة
cv2.imwrite("result5.jpg", image)
print("تم حفظ الصورة باسم result4.jpg")
# Out:
# 0: 288x640 14 persons, 1 sports ball, 305.4ms
# Speed: 39.1ms preprocess, 305.4ms inference, 16.0ms postprocess per image at shape (1, 3, 288, 640)
# تم حفظ الصورة باسم result4.jpg

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# تحميل النموذج المدرب
model = YOLO("yolov8n.pt")  # ضع هنا مسار النموذج المدرب على كرة القدم

# تحميل الصورة
image = cv2.imread("frame1.jpg")

# تشغيل الكشف
results = model(image)[0]

# استخراج الكائنات
players = []
ball = None

for result in results.boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    cls = int(cls)
    
    # نفترض أن الكلاس 0 هو لاعب، والكلاس 1 هو كرة (حسب التدريب الخاص بك)
    if cls == 0:  # لاعب
        center_x = int((x1 + x2) / 2)
        center_y = int((y1 + y2) / 2)
        players.append({'bbox': (int(x1), int(y1), int(x2), int(y2)), 'center': (center_x, center_y)})
    elif cls == 1:  # كرة
        ball = {'bbox': (int(x1), int(y1), int(x2), int(y2))}

# نفرض أن الفريق المهاجم على اليمين، والتسلل يتم بناءً على موضع الـ x
attacking_team = []
defending_team = []

# تصنيف الفرق بناءً على الموقع الأفقي (يمكن تحسينه لاحقاً بالألوان أو المعرفات)
median_x = np.median([p['center'][0] for p in players])
for p in players:
    if p['center'][0] > median_x:
        attacking_team.append(p)
    else:
        defending_team.append(p)

# تحديد آخر مدافع (أقصى قيمة x في الفريق المدافع)
last_defender_x = max([p['center'][0] for p in defending_team])

# تحديد اللاعبين المتسللين
offside_players = []
for p in attacking_team:
    if p['center'][0] > last_defender_x:
        offside_players.append(p)

# رسم النتائج
for p in players:
    x1, y1, x2, y2 = p['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)

for p in offside_players:
    x1, y1, x2, y2 = p['bbox']
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
    cv2.putText(image, "OFFSIDE", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

# رسم خط التسلل
cv2.line(image, (last_defender_x, 0), (last_defender_x, image.shape[0]), (0, 255, 255), 2)

# حفظ الصورة الناتجة
cv2.imwrite("result6.jpg", image)
# Out:
# 0: 288x640 14 persons, 1 sports ball, 304.6ms
# Speed: 6.5ms preprocess, 304.6ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
# True

# %%
import cv2
from ultralytics import YOLO

# تحميل نموذج YOLOv8
model = YOLO("yolov8n.pt")

# فتح الفيديو
video_path = "offside_example.MP4"  
cap = cv2.VideoCapture(video_path)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter("offside_result_1.mp4", cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # تحليل الفريم
    results = model(frame)[0]
    annotated_frame = results.plot()

    # جمع مواقع اللاعبين
    players = []
    for box in results.boxes:
        if int(box.cls[0]) == 0:  # class 0 = person
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            center_x = (x1 + x2) // 2
            players.append((center_x, x1, y1, x2, y2))

    # رسم خط التسلل
    if len(players) >= 2:
        players.sort(key=lambda p: p[0])  # حسب موقعهم الأفقي
        offside_line_x = players[-2][0]  # ثاني آخر مدافع
        cv2.line(annotated_frame, (offside_line_x, 0), (offside_line_x, height), (0, 255, 255), 2)

        # تحديد اللاعب المتسلل
        for player in players:
            center_x, x1, y1, x2, y2 = player
            if center_x > offside_line_x + 10:
                cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                cv2.putText(annotated_frame, "Offside", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

    out.write(annotated_frame)

cap.release()
out.release()
print("تم حفظ الفيديو الناتج باسم: offside_result_1.mp4")
# Out:
# 0: 352x640 15 persons, 772.3ms
# Speed: 140.1ms preprocess, 772.3ms inference, 68.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 186.6ms
# Speed: 8.0ms preprocess, 186.6ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 256.0ms
# Speed: 10.6ms preprocess, 256.0ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 235.7ms
# Speed: 7.2ms preprocess, 235.7ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 279.9ms
# Speed: 21.7ms preprocess, 279.9ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 254.1ms
# Speed: 10.3ms preprocess, 254.1ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 184.6ms
# Speed: 6.7ms preprocess, 184.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 389.1ms
# Speed: 14.2ms preprocess, 389.1ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 275.0ms
# Speed: 12.4ms preprocess, 275.0ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 211.0ms
# Speed: 8.5ms preprocess, 211.0ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 209.0ms
# Speed: 11.0ms preprocess, 209.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 228.5ms
# Speed: 7.4ms preprocess, 228.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 163.8ms
# Speed: 5.0ms preprocess, 163.8ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 176.4ms
# Speed: 7.5ms preprocess, 176.4ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 199.1ms
# Speed: 14.3ms preprocess, 199.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 166.1ms
# Speed: 7.6ms preprocess, 166.1ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 227.3ms
# Speed: 4.7ms preprocess, 227.3ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 279.7ms
# Speed: 7.4ms preprocess, 279.7ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 288.6ms
# Speed: 9.3ms preprocess, 288.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 386.6ms
# Speed: 9.7ms preprocess, 386.6ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 580.9ms
# Speed: 12.6ms preprocess, 580.9ms inference, 8.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 296.1ms
# Speed: 10.1ms preprocess, 296.1ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 301.0ms
# Speed: 20.7ms preprocess, 301.0ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 214.9ms
# Speed: 7.7ms preprocess, 214.9ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 243.1ms
# Speed: 6.5ms preprocess, 243.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 199.6ms
# Speed: 6.1ms preprocess, 199.6ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 223.4ms
# Speed: 5.3ms preprocess, 223.4ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 280.5ms
# Speed: 8.0ms preprocess, 280.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 255.2ms
# Speed: 7.2ms preprocess, 255.2ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 289.6ms
# Speed: 6.9ms preprocess, 289.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 233.9ms
# Speed: 6.9ms preprocess, 233.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 270.2ms
# Speed: 6.3ms preprocess, 270.2ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 211.8ms
# Speed: 15.1ms preprocess, 211.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 343.3ms
# Speed: 67.8ms preprocess, 343.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 168.5ms
# Speed: 4.7ms preprocess, 168.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 172.8ms
# Speed: 7.8ms preprocess, 172.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 195.9ms
# Speed: 7.4ms preprocess, 195.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 161.9ms
# Speed: 5.2ms preprocess, 161.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 159.4ms
# Speed: 4.6ms preprocess, 159.4ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 166.8ms
# Speed: 5.2ms preprocess, 166.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 240.3ms
# Speed: 5.4ms preprocess, 240.3ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 220.3ms
# Speed: 6.0ms preprocess, 220.3ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 271.2ms
# Speed: 7.5ms preprocess, 271.2ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 330.8ms
# Speed: 7.6ms preprocess, 330.8ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 246.5ms
# Speed: 14.0ms preprocess, 246.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 319.3ms
# Speed: 15.9ms preprocess, 319.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 202.9ms
# Speed: 9.2ms preprocess, 202.9ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 325.3ms
# Speed: 7.3ms preprocess, 325.3ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 214.6ms
# Speed: 5.4ms preprocess, 214.6ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 196.6ms
# Speed: 8.8ms preprocess, 196.6ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 222.9ms
# Speed: 6.3ms preprocess, 222.9ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 18 persons, 192.1ms
# Speed: 6.4ms preprocess, 192.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 171.7ms
# Speed: 6.7ms preprocess, 171.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 18 persons, 160.7ms
# Speed: 8.1ms preprocess, 160.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 164.9ms
# Speed: 5.8ms preprocess, 164.9ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 148.9ms
# Speed: 5.3ms preprocess, 148.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 239.7ms
# Speed: 9.6ms preprocess, 239.7ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 200.3ms
# Speed: 6.3ms preprocess, 200.3ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 187.7ms
# Speed: 12.7ms preprocess, 187.7ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 227.9ms
# Speed: 5.4ms preprocess, 227.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 158.8ms
# Speed: 5.0ms preprocess, 158.8ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 167.4ms
# Speed: 7.2ms preprocess, 167.4ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 184.1ms
# Speed: 5.2ms preprocess, 184.1ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 159.7ms
# Speed: 6.6ms preprocess, 159.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 188.0ms
# Speed: 5.2ms preprocess, 188.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 158.2ms
# Speed: 5.2ms preprocess, 158.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 151.1ms
# Speed: 4.5ms preprocess, 151.1ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 172.4ms
# Speed: 6.8ms preprocess, 172.4ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 174.1ms
# Speed: 6.2ms preprocess, 174.1ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 234.7ms
# Speed: 8.3ms preprocess, 234.7ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 232.9ms
# Speed: 13.0ms preprocess, 232.9ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 285.1ms
# Speed: 5.7ms preprocess, 285.1ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 717.7ms
# Speed: 11.1ms preprocess, 717.7ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 834.3ms
# Speed: 31.2ms preprocess, 834.3ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 19 persons, 226.2ms
# Speed: 11.5ms preprocess, 226.2ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 248.9ms
# Speed: 7.8ms preprocess, 248.9ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 18 persons, 216.7ms
# Speed: 6.5ms preprocess, 216.7ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 186.5ms
# Speed: 7.0ms preprocess, 186.5ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 157.1ms
# Speed: 7.6ms preprocess, 157.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 20 persons, 183.7ms
# Speed: 11.0ms preprocess, 183.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 411.5ms
# Speed: 6.9ms preprocess, 411.5ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 147.8ms
# Speed: 4.2ms preprocess, 147.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 18 persons, 162.9ms
# Speed: 4.1ms preprocess, 162.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 206.7ms
# Speed: 6.9ms preprocess, 206.7ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 191.5ms
# Speed: 10.8ms preprocess, 191.5ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 170.3ms
# Speed: 5.9ms preprocess, 170.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 163.6ms
# Speed: 5.5ms preprocess, 163.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 155.2ms
# Speed: 7.9ms preprocess, 155.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 17 persons, 181.7ms
# Speed: 5.1ms preprocess, 181.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 1 sports ball, 166.0ms
# Speed: 4.3ms preprocess, 166.0ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 18 persons, 160.7ms
# Speed: 5.1ms preprocess, 160.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 170.7ms
# Speed: 4.7ms preprocess, 170.7ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 18 persons, 146.4ms
# Speed: 5.7ms preprocess, 146.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 19 persons, 231.3ms
# Speed: 7.0ms preprocess, 231.3ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 468.4ms
# Speed: 6.8ms preprocess, 468.4ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 344.4ms
# Speed: 6.8ms preprocess, 344.4ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 1 sports ball, 406.0ms
# Speed: 7.4ms preprocess, 406.0ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 340.9ms
# Speed: 6.5ms preprocess, 340.9ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 1 sports ball, 215.0ms
# Speed: 12.1ms preprocess, 215.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 374.3ms
# Speed: 27.1ms preprocess, 374.3ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 191.8ms
# Speed: 4.7ms preprocess, 191.8ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 235.9ms
# Speed: 4.7ms preprocess, 235.9ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 166.9ms
# Speed: 5.6ms preprocess, 166.9ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 170.2ms
# Speed: 4.1ms preprocess, 170.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 259.3ms
# Speed: 7.9ms preprocess, 259.3ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 191.1ms
# Speed: 11.0ms preprocess, 191.1ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 183.7ms
# Speed: 5.0ms preprocess, 183.7ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 179.1ms
# Speed: 4.5ms preprocess, 179.1ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 151.0ms
# Speed: 6.8ms preprocess, 151.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 1 sports ball, 179.7ms
# Speed: 7.0ms preprocess, 179.7ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 162.6ms
# Speed: 5.0ms preprocess, 162.6ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 186.4ms
# Speed: 6.8ms preprocess, 186.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 182.5ms
# Speed: 5.1ms preprocess, 182.5ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 222.9ms
# Speed: 4.9ms preprocess, 222.9ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 276.0ms
# Speed: 7.9ms preprocess, 276.0ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 1 chair, 241.7ms
# Speed: 9.4ms preprocess, 241.7ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 278.9ms
# Speed: 13.2ms preprocess, 278.9ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 263.9ms
# Speed: 5.5ms preprocess, 263.9ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 257.5ms
# Speed: 14.8ms preprocess, 257.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 261.0ms
# Speed: 5.4ms preprocess, 261.0ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 227.6ms
# Speed: 7.5ms preprocess, 227.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 301.4ms
# Speed: 10.2ms preprocess, 301.4ms inference, 8.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 441.6ms
# Speed: 7.9ms preprocess, 441.6ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 461.6ms
# Speed: 12.4ms preprocess, 461.6ms inference, 15.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 451.1ms
# Speed: 20.6ms preprocess, 451.1ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 216.9ms
# Speed: 25.6ms preprocess, 216.9ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 208.9ms
# Speed: 6.7ms preprocess, 208.9ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 270.3ms
# Speed: 4.5ms preprocess, 270.3ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 1 sports ball, 268.9ms
# Speed: 18.6ms preprocess, 268.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 245.4ms
# Speed: 11.6ms preprocess, 245.4ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 499.2ms
# Speed: 4.5ms preprocess, 499.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 238.3ms
# Speed: 7.0ms preprocess, 238.3ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 1 sports ball, 166.6ms
# Speed: 4.3ms preprocess, 166.6ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 177.3ms
# Speed: 6.1ms preprocess, 177.3ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 1 sports ball, 188.5ms
# Speed: 27.6ms preprocess, 188.5ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 148.9ms
# Speed: 4.3ms preprocess, 148.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 184.5ms
# Speed: 4.8ms preprocess, 184.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 194.7ms
# Speed: 7.5ms preprocess, 194.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 232.5ms
# Speed: 4.7ms preprocess, 232.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 290.8ms
# Speed: 15.6ms preprocess, 290.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 292.6ms
# Speed: 6.5ms preprocess, 292.6ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 524.3ms
# Speed: 9.0ms preprocess, 524.3ms inference, 14.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 360.7ms
# Speed: 7.6ms preprocess, 360.7ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 788.6ms
# Speed: 6.7ms preprocess, 788.6ms inference, 9.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 308.1ms
# Speed: 13.1ms preprocess, 308.1ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 236.5ms
# Speed: 11.2ms preprocess, 236.5ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 308.2ms
# Speed: 14.7ms preprocess, 308.2ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 264.3ms
# Speed: 7.1ms preprocess, 264.3ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 310.5ms
# Speed: 9.7ms preprocess, 310.5ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 318.5ms
# Speed: 5.3ms preprocess, 318.5ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 333.6ms
# Speed: 5.3ms preprocess, 333.6ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 328.2ms
# Speed: 10.9ms preprocess, 328.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 299.6ms
# Speed: 15.6ms preprocess, 299.6ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 216.3ms
# Speed: 7.6ms preprocess, 216.3ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 229.4ms
# Speed: 5.6ms preprocess, 229.4ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 206.7ms
# Speed: 11.1ms preprocess, 206.7ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 239.3ms
# Speed: 25.9ms preprocess, 239.3ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 328.5ms
# Speed: 5.7ms preprocess, 328.5ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 1 sports ball, 304.7ms
# Speed: 11.1ms preprocess, 304.7ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 1 sports ball, 195.7ms
# Speed: 10.5ms preprocess, 195.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 sports ball, 1 tennis racket, 178.9ms
# Speed: 5.0ms preprocess, 178.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 1 sports ball, 169.3ms
# Speed: 4.9ms preprocess, 169.3ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 155.9ms
# Speed: 4.6ms preprocess, 155.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 1 sports ball, 177.6ms
# Speed: 10.6ms preprocess, 177.6ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 1 sports ball, 196.0ms
# Speed: 5.6ms preprocess, 196.0ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 172.6ms
# Speed: 5.6ms preprocess, 172.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 403.9ms
# Speed: 4.7ms preprocess, 403.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 154.0ms
# Speed: 4.6ms preprocess, 154.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 190.8ms
# Speed: 5.6ms preprocess, 190.8ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 1 sports ball, 180.8ms
# Speed: 6.8ms preprocess, 180.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 1 sports ball, 148.8ms
# Speed: 6.9ms preprocess, 148.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 186.0ms
# Speed: 4.8ms preprocess, 186.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 192.8ms
# Speed: 6.4ms preprocess, 192.8ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 278.9ms
# Speed: 12.4ms preprocess, 278.9ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 305.5ms
# Speed: 6.1ms preprocess, 305.5ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 292.6ms
# Speed: 5.5ms preprocess, 292.6ms inference, 5.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 326.6ms
# Speed: 16.7ms preprocess, 326.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 370.4ms
# Speed: 6.8ms preprocess, 370.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 297.2ms
# Speed: 23.4ms preprocess, 297.2ms inference, 6.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 248.3ms
# Speed: 8.8ms preprocess, 248.3ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 202.5ms
# Speed: 4.9ms preprocess, 202.5ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 216.8ms
# Speed: 4.5ms preprocess, 216.8ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 221.2ms
# Speed: 6.6ms preprocess, 221.2ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 199.7ms
# Speed: 6.9ms preprocess, 199.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 189.2ms
# Speed: 5.1ms preprocess, 189.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 156.4ms
# Speed: 4.9ms preprocess, 156.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 156.7ms
# Speed: 5.2ms preprocess, 156.7ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 216.1ms
# Speed: 4.2ms preprocess, 216.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 170.9ms
# Speed: 4.7ms preprocess, 170.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 154.3ms
# Speed: 4.8ms preprocess, 154.3ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 183.3ms
# Speed: 5.0ms preprocess, 183.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 346.1ms
# Speed: 4.2ms preprocess, 346.1ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 304.4ms
# Speed: 11.1ms preprocess, 304.4ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 272.3ms
# Speed: 5.2ms preprocess, 272.3ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 259.5ms
# Speed: 5.1ms preprocess, 259.5ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 398.0ms
# Speed: 9.2ms preprocess, 398.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 338.6ms
# Speed: 6.3ms preprocess, 338.6ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 402.5ms
# Speed: 5.0ms preprocess, 402.5ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 179.2ms
# Speed: 5.4ms preprocess, 179.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 151.5ms
# Speed: 5.9ms preprocess, 151.5ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 224.0ms
# Speed: 5.5ms preprocess, 224.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 sports ball, 157.3ms
# Speed: 4.8ms preprocess, 157.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 sports ball, 179.6ms
# Speed: 4.5ms preprocess, 179.6ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 157.9ms
# Speed: 5.1ms preprocess, 157.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 166.9ms
# Speed: 5.8ms preprocess, 166.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 195.4ms
# Speed: 4.3ms preprocess, 195.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 181.3ms
# Speed: 4.4ms preprocess, 181.3ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 157.2ms
# Speed: 5.2ms preprocess, 157.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 197.1ms
# Speed: 5.0ms preprocess, 197.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 181.6ms
# Speed: 4.7ms preprocess, 181.6ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 180.9ms
# Speed: 9.2ms preprocess, 180.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 172.3ms
# Speed: 5.1ms preprocess, 172.3ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 195.1ms
# Speed: 4.7ms preprocess, 195.1ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 168.7ms
# Speed: 6.2ms preprocess, 168.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 182.4ms
# Speed: 5.2ms preprocess, 182.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 170.6ms
# Speed: 4.3ms preprocess, 170.6ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 176.5ms
# Speed: 5.2ms preprocess, 176.5ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 178.0ms
# Speed: 4.3ms preprocess, 178.0ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 290.9ms
# Speed: 9.2ms preprocess, 290.9ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 289.9ms
# Speed: 5.6ms preprocess, 289.9ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 tennis racket, 505.5ms
# Speed: 6.0ms preprocess, 505.5ms inference, 6.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 tennis racket, 471.7ms
# Speed: 13.1ms preprocess, 471.7ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 tennis racket, 597.7ms
# Speed: 14.2ms preprocess, 597.7ms inference, 19.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 1 tennis racket, 308.4ms
# Speed: 13.5ms preprocess, 308.4ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 243.3ms
# Speed: 4.5ms preprocess, 243.3ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 550.8ms
# Speed: 4.7ms preprocess, 550.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 239.8ms
# Speed: 8.2ms preprocess, 239.8ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 213.1ms
# Speed: 5.8ms preprocess, 213.1ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 188.7ms
# Speed: 8.7ms preprocess, 188.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 189.0ms
# Speed: 5.3ms preprocess, 189.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 205.6ms
# Speed: 5.3ms preprocess, 205.6ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 422.1ms
# Speed: 4.4ms preprocess, 422.1ms inference, 33.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 475.1ms
# Speed: 19.9ms preprocess, 475.1ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 301.1ms
# Speed: 6.3ms preprocess, 301.1ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 254.0ms
# Speed: 5.8ms preprocess, 254.0ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 264.9ms
# Speed: 7.9ms preprocess, 264.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 sports ball, 180.5ms
# Speed: 4.4ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 213.3ms
# Speed: 6.2ms preprocess, 213.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 168.7ms
# Speed: 4.2ms preprocess, 168.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 177.0ms
# Speed: 4.4ms preprocess, 177.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 222.7ms
# Speed: 5.5ms preprocess, 222.7ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 198.0ms
# Speed: 5.1ms preprocess, 198.0ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 199.2ms
# Speed: 4.4ms preprocess, 199.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 191.3ms
# Speed: 4.3ms preprocess, 191.3ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 180.6ms
# Speed: 4.4ms preprocess, 180.6ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 170.5ms
# Speed: 5.3ms preprocess, 170.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 205.3ms
# Speed: 6.1ms preprocess, 205.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 191.3ms
# Speed: 4.3ms preprocess, 191.3ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 186.3ms
# Speed: 5.6ms preprocess, 186.3ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 411.0ms
# Speed: 4.5ms preprocess, 411.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 164.6ms
# Speed: 4.6ms preprocess, 164.6ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 174.4ms
# Speed: 5.6ms preprocess, 174.4ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 192.6ms
# Speed: 5.2ms preprocess, 192.6ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 190.6ms
# Speed: 5.6ms preprocess, 190.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 sports ball, 211.4ms
# Speed: 4.1ms preprocess, 211.4ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 sports ball, 186.7ms
# Speed: 5.1ms preprocess, 186.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 sports ball, 256.0ms
# Speed: 9.2ms preprocess, 256.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 400.6ms
# Speed: 7.1ms preprocess, 400.6ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 429.2ms
# Speed: 6.1ms preprocess, 429.2ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 440.6ms
# Speed: 7.2ms preprocess, 440.6ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 523.3ms
# Speed: 6.2ms preprocess, 523.3ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 317.9ms
# Speed: 9.1ms preprocess, 317.9ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 252.0ms
# Speed: 11.3ms preprocess, 252.0ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 223.5ms
# Speed: 5.3ms preprocess, 223.5ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 204.4ms
# Speed: 4.7ms preprocess, 204.4ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 255.5ms
# Speed: 4.5ms preprocess, 255.5ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 285.2ms
# Speed: 7.7ms preprocess, 285.2ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 278.6ms
# Speed: 7.3ms preprocess, 278.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 171.6ms
# Speed: 4.6ms preprocess, 171.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 207.4ms
# Speed: 4.3ms preprocess, 207.4ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 180.3ms
# Speed: 4.3ms preprocess, 180.3ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 205.9ms
# Speed: 4.4ms preprocess, 205.9ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 644.3ms
# Speed: 10.0ms preprocess, 644.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
# تم حفظ الفيديو الناتج باسم: offside_result_1.mp4
